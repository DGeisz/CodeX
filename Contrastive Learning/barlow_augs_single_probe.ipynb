# %%
import importlib
import torch
import torchvision


from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
from pathlib import Path
from augs import AugTransform

import time
import learning_loop

from learning_loop import BATCH_SIZE

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
BATCH_SIZE
# Out:
# 64

# %%
import models

BarlowTwins = models.BauglowTwins

# %%
def reload():
    importlib.reload(learning_loop)
    importlib.reload(models)

    global BATCH_SIZE, BarlowTwins, a_loop

    a_loop = learning_loop.aug_learning_loop_single_probe
    BATCH_SIZE = learning_loop.BATCH_SIZE
    BarlowTwins = models.BauglowTwins

# %%
stl = datasets.STL10(
    root="data",
    split="train",
    download=True,
    transform=AugTransform()
)
# Out:
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/torchvision/transforms/transforms.py:899: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# Files already downloaded and verified

# %%
stl_loader = DataLoader(stl, batch_size=BATCH_SIZE)
data, cls = next(iter(stl_loader))

# %%
reload()
model = BarlowTwins(BATCH_SIZE, use_sqrt=False).to(device)

# %%
model.name
# Out:
# 'augs_no_sqrt_single_probe'

# %%
x, y = data
x, y = x.cuda(), y.cuda()

# %%
# !nvidia-smi
# Out:
# Thu Jan  5 16:37:34 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.65.01    Driver Version: 515.65.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   34C    P0    46W / 300W |   1039MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2286      C   ...a/envs/pytorch/bin/python     1037MiB |
# +-----------------------------------------------------------------------------+

# %%
reload()

a_loop(
    model,
    dataset=stl,
    probe_data=(x, y),
    output_dir="aug_no_sq_high_i_single_probe",
    delete_existing_dir=True
)
# Out:
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/ipykernel_launcher.py -f /home/ubuntu/.local/share/jupyter/runtime/kernel-adafb7b8-ba86-41a4-b569-8198d5604f83.json
# Starting Eigen Comp
# Ending Eigen Comp 2.9619219303131104 sec
# {"epoch": 0, "step": 0, "lr_weights": 0.0, "lr_biases": 0.0, "loss": 511.998779296875, "time": 1}
# [0.000143482320709154, 0.00011246783833485097, 8.691145194461569e-05, 2.243995368189644e-05, 1.9613196855061688e-05]
# Starting Eigen Comp
# Ending Eigen Comp 0.1372208595275879 sec
# {"epoch": 0, "step": 25, "lr_weights": 0.0015822784810126584, "lr_biases": 3.79746835443038e-05, "loss": 511.9988708496094, "time": 37}
# [0.00015863434236962348, 0.0001204006330226548, 9.227023110724986e-05, 2.3078720914782025e-05, 2.028215203608852e-05]
# Starting Eigen Comp
# Ending Eigen Comp 0.13111495971679688 sec
# {"epoch": 0, "step": 50, "lr_weights": 0.003164556962025317, "lr_biases": 7.59493670886076e-05, "loss": 511.99859619140625, "time": 70}
# [0.0002317452454008162, 0.0001479515340179205, 0.00011260775499977171, 2.5557528715580702e-05, 2.2831894966657273e-05]
# Starting Eigen Comp
# Ending Eigen Comp 0.1309523582458496 sec
# {"epoch": 0, "step": 75, "lr_weights": 0.004746835443037976, "lr_biases": 0.00011392405063291139, "loss": 511.99798583984375, "time": 104}
# [0.0004432223504409194, 0.0002219356974819675, 0.00016038691683206707, 3.085698335780762e-05, 2.7037969630328007e-05]
# Starting Eigen Comp
# Ending Eigen Comp 0.1293954849243164 sec
# {"epoch": 1, "step": 100, "lr_weights": 0.006329113924050634, "lr_biases": 0.0001518987341772152, "loss": 511.99688720703125, "time": 136}
# [0.0010289625497534871, 0.00037306477315723896, 0.0002548427728470415, 3.961375114158727e-05, 3.384548836038448e-05]
# Starting Eigen Comp
# Ending Eigen Comp 0.1287975311279297 sec
# {"epoch": 1, "step": 125, "lr_weights": 0.007911392405063292, "lr_biases": 0.00018987341772151899, "loss": 511.9919128417969, "time": 170}
# [0.0032100107055157423, 0.0006993079441599548, 0.00043939726310782135, 5.6143602705560625e-05, 4.63508658867795e-05]
# Starting Eigen Comp
# Ending Eigen Comp 0.12781739234924316 sec
# {"epoch": 1, "step": 150, "lr_weights": 0.009493670886075951, "lr_biases": 0.00022784810126582277, "loss": 511.97308349609375, "time": 203}
# [0.012537561357021332, 0.0013410105602815747, 0.0007931652944535017, 8.399648504564539e-05, 6.791228952351958e-05]
# Starting Eigen Comp
# Ending Eigen Comp 0.12761783599853516 sec
# {"epoch": 2, "step": 175, "lr_weights": 0.011075949367088608, "lr_biases": 0.00026582278481012653, "loss": 511.8431396484375, "time": 236}
# [0.06574872136116028, 0.0024177224840968847, 0.001268210937269032, 0.00012776037328876555, 0.00011100861593149602]
# Starting Eigen Comp
# Ending Eigen Comp 0.12456989288330078 sec
# {"epoch": 2, "step": 200, "lr_weights": 0.012658227848101267, "lr_biases": 0.0003037974683544304, "loss": 511.11871337890625, "time": 269}
# [0.5446902513504028, 0.0047834208235144615, 0.002013408113270998, 0.0002569911302998662, 0.00018724199617281556]
# Starting Eigen Comp
# Ending Eigen Comp 0.12527823448181152 sec
# {"epoch": 2, "step": 225, "lr_weights": 0.014240506329113925, "lr_biases": 0.00034177215189873416, "loss": 511.03607177734375, "time": 302}
# [0.7588889598846436, 0.007570622023195028, 0.004033994860947132, 0.00037366070318967104, 0.00022604929108638316]
# Starting Eigen Comp
# Ending Eigen Comp 0.12452006340026855 sec
# {"epoch": 3, "step": 250, "lr_weights": 0.015822784810126583, "lr_biases": 0.00037974683544303797, "loss": 511.0499267578125, "time": 335}
# [1.0054945945739746, 0.013398037292063236, 0.006376064382493496, 0.00047289434587582946, 0.0002777316840365529]
# Starting Eigen Comp
# Ending Eigen Comp 0.12650728225708008 sec
# {"epoch": 3, "step": 275, "lr_weights": 0.017405063291139243, "lr_biases": 0.0004177215189873418, "loss": 510.95703125, "time": 368}
# [1.0012612342834473, 0.029238546267151833, 0.012542839162051678, 0.0006820819107815623, 0.00037815500400029123]
# Starting Eigen Comp
# Ending Eigen Comp 0.12435698509216309 sec
# {"epoch": 3, "step": 300, "lr_weights": 0.018987341772151903, "lr_biases": 0.00045569620253164554, "loss": 510.9111328125, "time": 401}
# [0.8182908892631531, 0.07285907864570618, 0.02235092967748642, 0.0010224503930658102, 0.00058317108778283]
# Starting Eigen Comp
# Ending Eigen Comp 0.12457895278930664 sec
# {"epoch": 4, "step": 325, "lr_weights": 0.02056962025316456, "lr_biases": 0.0004936708860759494, "loss": 510.6269226074219, "time": 434}
# [1.0688390731811523, 0.29211512207984924, 0.03404603525996208, 0.0023946750443428755, 0.0009472962701693177]
# Starting Eigen Comp
# Ending Eigen Comp 0.12588000297546387 sec
# {"epoch": 4, "step": 350, "lr_weights": 0.022151898734177215, "lr_biases": 0.0005316455696202531, "loss": 510.50494384765625, "time": 467}
# [1.4839398860931396, 0.828421950340271, 0.05846861004829407, 0.006038361694663763, 0.0014191658701747656]
# Starting Eigen Comp
# Ending Eigen Comp 0.12728095054626465 sec
# {"epoch": 4, "step": 375, "lr_weights": 0.023734177215189875, "lr_biases": 0.0005696202531645569, "loss": 509.7897033691406, "time": 500}
# [1.3009274005889893, 0.96647709608078, 0.1454344391822815, 0.008682521060109138, 0.002370720263570547]
# Starting Eigen Comp
# Ending Eigen Comp 0.12620139122009277 sec
# {"epoch": 5, "step": 400, "lr_weights": 0.025316455696202535, "lr_biases": 0.0006075949367088608, "loss": 509.5257873535156, "time": 533}
# [1.1499474048614502, 0.6564676761627197, 0.37971606850624084, 0.01005389355123043, 0.0036557286512106657]
# Starting Eigen Comp
# Ending Eigen Comp 0.12592673301696777 sec
# {"epoch": 5, "step": 425, "lr_weights": 0.02689873417721519, "lr_biases": 0.0006455696202531645, "loss": 509.6942138671875, "time": 566}
# [1.3773115873336792, 0.841778039932251, 0.5549142360687256, 0.015434131026268005, 0.005161353386938572]
# Starting Eigen Comp
# Ending Eigen Comp 0.12742114067077637 sec
# {"epoch": 5, "step": 450, "lr_weights": 0.02848101265822785, "lr_biases": 0.0006835443037974683, "loss": 508.9832458496094, "time": 600}
# [1.6605829000473022, 1.0413230657577515, 0.5819539427757263, 0.02529446966946125, 0.005971179809421301]
# Starting Eigen Comp
# Ending Eigen Comp 0.127471923828125 sec
# {"epoch": 6, "step": 475, "lr_weights": 0.030063291139240507, "lr_biases": 0.000721518987341772, "loss": 510.0351257324219, "time": 632}
# [1.579970359802246, 0.7896595001220703, 0.5657210946083069, 0.032329071313142776, 0.007303955499082804]
# Starting Eigen Comp
# Ending Eigen Comp 0.12634849548339844 sec
# {"epoch": 6, "step": 500, "lr_weights": 0.03164556962025317, "lr_biases": 0.0007594936708860759, "loss": 509.6094055175781, "time": 666}
# [1.3934675455093384, 0.7535557746887207, 0.46825066208839417, 0.039840277284383774, 0.008443067781627178]
# Starting Eigen Comp
# Ending Eigen Comp 0.12769055366516113 sec
# {"epoch": 6, "step": 525, "lr_weights": 0.033227848101265826, "lr_biases": 0.0007974683544303796, "loss": 509.2715148925781, "time": 699}
# [1.398758053779602, 0.7602857351303101, 0.561043918132782, 0.09805557876825333, 0.01136537455022335]
# Starting Eigen Comp
# Ending Eigen Comp 0.12914752960205078 sec
# {"epoch": 6, "step": 550, "lr_weights": 0.034810126582278486, "lr_biases": 0.0008354430379746836, "loss": 509.380615234375, "time": 732}
# [1.2665222883224487, 0.7822105288505554, 0.5022669434547424, 0.2212112843990326, 0.01622113399207592]
# Starting Eigen Comp
# Ending Eigen Comp 0.12749934196472168 sec
# {"epoch": 7, "step": 575, "lr_weights": 0.03639240506329114, "lr_biases": 0.0008734177215189873, "loss": 509.0278625488281, "time": 764}
# [1.4507145881652832, 0.9648709893226624, 0.709024965763092, 0.24405747652053833, 0.0190032497048378]
# Starting Eigen Comp
# Ending Eigen Comp 0.12946629524230957 sec
# {"epoch": 7, "step": 600, "lr_weights": 0.037974683544303806, "lr_biases": 0.0009113924050632911, "loss": 508.5335998535156, "time": 797}
# [1.1634713411331177, 0.8808203339576721, 0.5116268396377563, 0.24847638607025146, 0.02051449380815029]
# Starting Eigen Comp
# Ending Eigen Comp 0.12857961654663086 sec
# {"epoch": 7, "step": 625, "lr_weights": 0.03955696202531646, "lr_biases": 0.0009493670886075949, "loss": 508.962646484375, "time": 830}
# [1.1652976274490356, 1.0780506134033203, 0.48078951239585876, 0.27278590202331543, 0.026998402550816536]
# Starting Eigen Comp
# Ending Eigen Comp 0.12929677963256836 sec
# {"epoch": 8, "step": 650, "lr_weights": 0.04113924050632912, "lr_biases": 0.0009873417721518987, "loss": 508.33905029296875, "time": 863}
# [1.4337756633758545, 0.8498097658157349, 0.6404005885124207, 0.19674502313137054, 0.030023282393813133]
# Starting Eigen Comp
# Ending Eigen Comp 0.12780499458312988 sec
# {"epoch": 8, "step": 675, "lr_weights": 0.04272151898734178, "lr_biases": 0.0010253164556962024, "loss": 508.9643249511719, "time": 896}
# [1.47800874710083, 1.2491672039031982, 0.562156617641449, 0.29555758833885193, 0.03191324695944786]
# Starting Eigen Comp
# Ending Eigen Comp 0.12859368324279785 sec
# {"epoch": 8, "step": 700, "lr_weights": 0.04430379746835443, "lr_biases": 0.0010632911392405061, "loss": 509.0597839355469, "time": 929}
# [1.347904920578003, 1.2306239604949951, 0.6416738629341125, 0.26974549889564514, 0.042747996747493744]
# Starting Eigen Comp
# Ending Eigen Comp 0.12887024879455566 sec
# {"epoch": 9, "step": 725, "lr_weights": 0.04588607594936709, "lr_biases": 0.00110126582278481, "loss": 508.2882080078125, "time": 962}
# [1.323146939277649, 0.8136727213859558, 0.46287357807159424, 0.27946358919143677, 0.06541172415018082]
# Starting Eigen Comp
# Ending Eigen Comp 0.12869596481323242 sec
# {"epoch": 9, "step": 750, "lr_weights": 0.04746835443037975, "lr_biases": 0.0011392405063291138, "loss": 509.26361083984375, "time": 995}
# [1.427375316619873, 0.9408819675445557, 0.49693286418914795, 0.29213839769363403, 0.0981852263212204]
# Starting Eigen Comp
# Ending Eigen Comp 0.12836813926696777 sec
# {"epoch": 9, "step": 775, "lr_weights": 0.04905063291139241, "lr_biases": 0.0011772151898734177, "loss": 509.07366943359375, "time": 1029}
# [1.447229266166687, 1.0190190076828003, 0.6640099287033081, 0.3388995826244354, 0.16247043013572693]
# Starting Eigen Comp
# Ending Eigen Comp 0.13004517555236816 sec
# {"epoch": 10, "step": 800, "lr_weights": 0.04999999798511312, "lr_biases": 0.0011999999516427147, "loss": 508.34600830078125, "time": 1062}
# [1.612466812133789, 1.1469568014144897, 0.6065477132797241, 0.2968670129776001, 0.21774986386299133]
# Starting Eigen Comp
# Ending Eigen Comp 0.12794733047485352 sec
# {"epoch": 10, "step": 825, "lr_weights": 0.04999997531763946, "lr_biases": 0.0011999994076233467, "loss": 508.0249328613281, "time": 1095}
# [1.1576422452926636, 0.9341989159584045, 0.4270939826965332, 0.3285914361476898, 0.2317979633808136]
# Starting Eigen Comp
# Ending Eigen Comp 0.1279900074005127 sec
# {"epoch": 10, "step": 850, "lr_weights": 0.04999992746410645, "lr_biases": 0.0011999982591385547, "loss": 508.1587829589844, "time": 1128}
# [1.5305408239364624, 0.9151028394699097, 0.6444577574729919, 0.27383744716644287, 0.13175548613071442]
# Starting Eigen Comp
# Ending Eigen Comp 0.12769651412963867 sec
# {"epoch": 11, "step": 875, "lr_weights": 0.04999985442456237, "lr_biases": 0.0011999965061894966, "loss": 509.9031982421875, "time": 1161}
# [1.684312105178833, 0.7776001691818237, 0.5266014933586121, 0.3726217448711395, 0.0758780688047409]
# Starting Eigen Comp
# Ending Eigen Comp 0.12778091430664062 sec
# {"epoch": 11, "step": 900, "lr_weights": 0.04999975619908087, "lr_biases": 0.0011999941487779407, "loss": 508.0711669921875, "time": 1195}
# [1.7057092189788818, 1.1653858423233032, 0.7774142622947693, 0.5203033089637756, 0.30238208174705505]
# Starting Eigen Comp
# Ending Eigen Comp 0.12770795822143555 sec
# {"epoch": 11, "step": 925, "lr_weights": 0.049999632787761004, "lr_biases": 0.001199991186906264, "loss": 508.52734375, "time": 1228}
# [1.6590560674667358, 1.0379465818405151, 0.8671613335609436, 0.6186746954917908, 0.37466779351234436]
# Starting Eigen Comp
# Ending Eigen Comp 0.13092970848083496 sec
# {"epoch": 12, "step": 950, "lr_weights": 0.049999484190727236, "lr_biases": 0.0011999876205774536, "loss": 507.2374572753906, "time": 1260}
# [1.6871339082717896, 1.0276740789413452, 0.9177566170692444, 0.634296178817749, 0.37987038493156433]
# Starting Eigen Comp
# Ending Eigen Comp 0.1287529468536377 sec
# {"epoch": 12, "step": 975, "lr_weights": 0.04999931040812941, "lr_biases": 0.0011999834497951056, "loss": 508.6406555175781, "time": 1293}
# [1.7115399837493896, 1.029158115386963, 0.7492925524711609, 0.5988157987594604, 0.3336927592754364]
# Starting Eigen Comp
# Ending Eigen Comp 0.12945032119750977 sec
# {"epoch": 12, "step": 1000, "lr_weights": 0.049999111440142775, "lr_biases": 0.0011999786745634264, "loss": 507.9212951660156, "time": 1327}
# [1.5425447225570679, 0.9628032445907593, 0.9113722443580627, 0.4823307394981384, 0.36047616600990295]
# Starting Eigen Comp
# Ending Eigen Comp 0.12782573699951172 sec
# {"epoch": 12, "step": 1025, "lr_weights": 0.04999888728696798, "lr_biases": 0.0011999732948872314, "loss": 508.1166076660156, "time": 1360}
# [1.1586978435516357, 1.0608645677566528, 0.6848998665809631, 0.5946908593177795, 0.5019007325172424]
# Starting Eigen Comp
# Ending Eigen Comp 0.12780976295471191 sec
# {"epoch": 13, "step": 1050, "lr_weights": 0.04999863794883108, "lr_biases": 0.0011999673107719459, "loss": 507.4951477050781, "time": 1393}
# [1.3951815366744995, 0.9572445750236511, 0.652775764465332, 0.5454707741737366, 0.31905099749565125]
# Starting Eigen Comp
# Ending Eigen Comp 0.12951374053955078 sec
# {"epoch": 13, "step": 1075, "lr_weights": 0.04999836342598353, "lr_biases": 0.0011999607222236046, "loss": 509.1261901855469, "time": 1426}
# [1.625836730003357, 1.0622460842132568, 0.5982946753501892, 0.4849558472633362, 0.3150467574596405]
# Starting Eigen Comp
# Ending Eigen Comp 0.12932586669921875 sec
# {"epoch": 13, "step": 1100, "lr_weights": 0.049998063718702156, "lr_biases": 0.0011999535292488515, "loss": 507.212890625, "time": 1459}
# [1.4119709730148315, 1.1492211818695068, 0.7444925308227539, 0.45736703276634216, 0.3635038435459137]
# Starting Eigen Comp
# Ending Eigen Comp 0.1295332908630371 sec
# {"epoch": 14, "step": 1125, "lr_weights": 0.049997738827289195, "lr_biases": 0.0011999457318549406, "loss": 507.44708251953125, "time": 1492}
# [1.4222710132598877, 1.0461333990097046, 0.7758395075798035, 0.585004448890686, 0.3531147241592407]
# Starting Eigen Comp
# Ending Eigen Comp 0.12915849685668945 sec
# {"epoch": 14, "step": 1150, "lr_weights": 0.0499973887520723, "lr_biases": 0.001199937330049735, "loss": 507.55352783203125, "time": 1525}
# [1.1352581977844238, 1.0078741312026978, 0.6531165838241577, 0.492477148771286, 0.41230320930480957]
# Starting Eigen Comp
# Ending Eigen Comp 0.12950849533081055 sec
# {"epoch": 14, "step": 1175, "lr_weights": 0.04999701349340449, "lr_biases": 0.0011999283238417076, "loss": 507.1228332519531, "time": 1559}
# [1.6560639142990112, 0.9618918895721436, 0.8544122576713562, 0.6381340622901917, 0.5135267972946167]
# Starting Eigen Comp
# Ending Eigen Comp 0.13012170791625977 sec
# {"epoch": 15, "step": 1200, "lr_weights": 0.04999661305166421, "lr_biases": 0.001199918713239941, "loss": 507.23272705078125, "time": 1591}
# [1.6871869564056396, 1.3721338510513306, 0.9689159393310547, 0.8097974061965942, 0.7654436826705933]
# Starting Eigen Comp
# Ending Eigen Comp 0.12970495223999023 sec
# {"epoch": 15, "step": 1225, "lr_weights": 0.04999618742725528, "lr_biases": 0.0011999084982541265, "loss": 507.1699523925781, "time": 1625}
# [1.7210605144500732, 1.2445274591445923, 0.8510025143623352, 0.6716269254684448, 0.5970346331596375]
# Starting Eigen Comp
# Ending Eigen Comp 0.12924909591674805 sec
# {"epoch": 15, "step": 1250, "lr_weights": 0.04999573662060691, "lr_biases": 0.0011998976788945657, "loss": 506.40087890625, "time": 1658}
# [1.6068576574325562, 1.3505144119262695, 0.9089921712875366, 0.8100126385688782, 0.5796957015991211]
# Starting Eigen Comp
# Ending Eigen Comp 0.1293795108795166 sec
# {"epoch": 16, "step": 1275, "lr_weights": 0.04999526063217374, "lr_biases": 0.0011998862551721695, "loss": 506.99212646484375, "time": 1691}
# [1.6328308582305908, 1.087149739265442, 0.954191267490387, 0.6907294392585754, 0.49339398741722107]
# Starting Eigen Comp
# Ending Eigen Comp 0.1304643154144287 sec
# {"epoch": 16, "step": 1300, "lr_weights": 0.04999475946243576, "lr_biases": 0.0011998742270984582, "loss": 508.0443115234375, "time": 1724}
# [1.4611842632293701, 1.1403273344039917, 0.7913715243339539, 0.6139523983001709, 0.4067184329032898]
# Starting Eigen Comp
# Ending Eigen Comp 0.1294848918914795 sec
# {"epoch": 16, "step": 1325, "lr_weights": 0.04999423311189839, "lr_biases": 0.0011998615946855612, "loss": 507.6349182128906, "time": 1757}
# [1.7732856273651123, 1.1996721029281616, 0.9951218366622925, 0.7091166377067566, 0.6066778898239136]
# Starting Eigen Comp
# Ending Eigen Comp 0.1307060718536377 sec
# {"epoch": 17, "step": 1350, "lr_weights": 0.04999368158109242, "lr_biases": 0.001199848357946218, "loss": 506.76153564453125, "time": 1791}
# [1.7041504383087158, 1.4661020040512085, 1.016555666923523, 0.656724214553833, 0.46839797496795654]
# Starting Eigen Comp
# Ending Eigen Comp 0.13091444969177246 sec
# {"epoch": 17, "step": 1375, "lr_weights": 0.04999310487057405, "lr_biases": 0.001199834516893777, "loss": 507.022216796875, "time": 1824}
# [1.7210261821746826, 1.2822033166885376, 1.1570645570755005, 0.6466051340103149, 0.5440521836280823]
# Starting Eigen Comp
# Ending Eigen Comp 0.13071155548095703 sec
# {"epoch": 17, "step": 1400, "lr_weights": 0.049992502980924856, "lr_biases": 0.0011998200715421963, "loss": 507.56500244140625, "time": 1857}
# [1.6036484241485596, 1.4318641424179077, 0.834571123123169, 0.6011629700660706, 0.5606170892715454]
# Starting Eigen Comp
# Ending Eigen Comp 0.12939023971557617 sec
# {"epoch": 18, "step": 1425, "lr_weights": 0.049991875912751824, "lr_biases": 0.0011998050219060436, "loss": 506.6206359863281, "time": 1890}
# [2.0372517108917236, 1.577696442604065, 0.8530991077423096, 0.6240040063858032, 0.5555856823921204]
# Starting Eigen Comp
# Ending Eigen Comp 0.131605863571167 sec
# {"epoch": 18, "step": 1450, "lr_weights": 0.04999122366668732, "lr_biases": 0.0011997893680004955, "loss": 507.215087890625, "time": 1923}
# [1.5492490530014038, 1.195651888847351, 1.0361038446426392, 0.6391569972038269, 0.5959913730621338]
# Starting Eigen Comp
# Ending Eigen Comp 0.1302647590637207 sec
# {"epoch": 18, "step": 1475, "lr_weights": 0.04999054624338909, "lr_biases": 0.001199773109841338, "loss": 506.361328125, "time": 1956}
# [1.639344334602356, 1.539698839187622, 0.9333747029304504, 0.715331494808197, 0.5017109513282776]
# Starting Eigen Comp
# Ending Eigen Comp 0.13012361526489258 sec
# {"epoch": 18, "step": 1500, "lr_weights": 0.049989843643540297, "lr_biases": 0.001199756247444967, "loss": 510.9171447753906, "time": 1988}
# [1.4770044088363647, 1.2338117361068726, 0.7843559980392456, 0.5730976462364197, 0.4397415816783905]
# Starting Eigen Comp
# Ending Eigen Comp 0.13168907165527344 sec
# {"epoch": 19, "step": 1525, "lr_weights": 0.04998911586784948, "lr_biases": 0.0011997387808283873, "loss": 505.7743225097656, "time": 2022}
# [1.5947411060333252, 1.4455384016036987, 1.0192633867263794, 0.7961172461509705, 0.7004051208496094]
# Starting Eigen Comp
# Ending Eigen Comp 0.13060235977172852 sec
# {"epoch": 19, "step": 1550, "lr_weights": 0.04998836291705055, "lr_biases": 0.001199720710009213, "loss": 506.24151611328125, "time": 2055}
# [1.587894082069397, 1.386561393737793, 0.8616501688957214, 0.7001721858978271, 0.594693660736084]
# Starting Eigen Comp
# Ending Eigen Comp 0.1309506893157959 sec
# {"epoch": 19, "step": 1575, "lr_weights": 0.049987584791902843, "lr_biases": 0.001199702035005668, "loss": 505.11798095703125, "time": 2089}
# [1.8422702550888062, 1.3826717138290405, 0.9164189100265503, 0.8427703976631165, 0.6803892254829407]
# Starting Eigen Comp
# Ending Eigen Comp 0.13134121894836426 sec
# {"epoch": 20, "step": 1600, "lr_weights": 0.04998678149319105, "lr_biases": 0.001199682755836585, "loss": 507.1615295410156, "time": 2122}
# [1.7491458654403687, 1.312705397605896, 0.9603902101516724, 0.6323444247245789, 0.5286030769348145]
# Starting Eigen Comp
# Ending Eigen Comp 0.13095903396606445 sec
# {"epoch": 20, "step": 1625, "lr_weights": 0.04998595302172525, "lr_biases": 0.0011996628725214058, "loss": 507.2818603515625, "time": 2155}
# [1.512274980545044, 1.2811968326568604, 0.9424332976341248, 0.6979873776435852, 0.5671098828315735]
# Starting Eigen Comp
# Ending Eigen Comp 0.1307358741760254 sec
# {"epoch": 20, "step": 1650, "lr_weights": 0.049985099378340926, "lr_biases": 0.001199642385080182, "loss": 506.278076171875, "time": 2188}
# [1.4476393461227417, 1.2137348651885986, 1.0806571245193481, 0.8252313137054443, 0.64774489402771]
# Starting Eigen Comp
# Ending Eigen Comp 0.12958741188049316 sec
# {"epoch": 21, "step": 1675, "lr_weights": 0.049984220563898944, "lr_biases": 0.0011996212935335745, "loss": 504.1717834472656, "time": 2221}
# [1.8619043827056885, 1.4873337745666504, 0.9132131338119507, 0.7041360139846802, 0.521663248538971]
# Starting Eigen Comp
# Ending Eigen Comp 0.1312119960784912 sec
# {"epoch": 21, "step": 1700, "lr_weights": 0.049983316579285536, "lr_biases": 0.0011995995979028529, "loss": 505.5428466796875, "time": 2254}
# [1.5800930261611938, 1.1969621181488037, 0.9533737897872925, 0.8549954891204834, 0.5949811339378357]
# Starting Eigen Comp
# Ending Eigen Comp 0.1308913230895996 sec
# {"epoch": 21, "step": 1725, "lr_weights": 0.04998238742541233, "lr_biases": 0.0011995772982098956, "loss": 505.6750183105469, "time": 2288}
# [1.4909155368804932, 1.4668339490890503, 0.9273970127105713, 0.7120357751846313, 0.5718848705291748]
# Starting Eigen Comp
# Ending Eigen Comp 0.1315908432006836 sec
# {"epoch": 22, "step": 1750, "lr_weights": 0.04998143310321632, "lr_biases": 0.0011995543944771916, "loss": 506.5853576660156, "time": 2321}
# [1.8540464639663696, 1.3780075311660767, 0.9754572510719299, 0.8322635293006897, 0.5668338537216187]
# Starting Eigen Comp
# Ending Eigen Comp 0.1318967342376709 sec
# {"epoch": 22, "step": 1775, "lr_weights": 0.049980453613659916, "lr_biases": 0.001199530886727838, "loss": 506.6876220703125, "time": 2354}
# [1.6715481281280518, 1.3208446502685547, 0.9604461789131165, 0.7152312994003296, 0.5753524303436279]
# Starting Eigen Comp
# Ending Eigen Comp 0.13155484199523926 sec
# {"epoch": 22, "step": 1800, "lr_weights": 0.049979448957730876, "lr_biases": 0.001199506774985541, "loss": 506.25555419921875, "time": 2387}
# [1.7713782787322998, 1.3625737428665161, 0.998482346534729, 0.9261121153831482, 0.6146823167800903]
# Starting Eigen Comp
# Ending Eigen Comp 0.13056707382202148 sec
# {"epoch": 23, "step": 1825, "lr_weights": 0.04997841913644235, "lr_biases": 0.001199482059274616, "loss": 505.5384216308594, "time": 2420}
# [1.759980320930481, 1.3969333171844482, 0.9218372106552124, 0.7906754016876221, 0.5551357269287109]
# Starting Eigen Comp
# Ending Eigen Comp 0.13048839569091797 sec
# {"epoch": 23, "step": 1850, "lr_weights": 0.049977364150832856, "lr_biases": 0.0011994567396199883, "loss": 504.99090576171875, "time": 2453}
# [1.5339579582214355, 1.3720767498016357, 1.025991678237915, 0.6444690823554993, 0.45548006892204285]
# Starting Eigen Comp
# Ending Eigen Comp 0.13086724281311035 sec
# {"epoch": 23, "step": 1875, "lr_weights": 0.0499762840019663, "lr_biases": 0.001199430816047191, "loss": 505.7229919433594, "time": 2487}
# [1.5922034978866577, 1.51691734790802, 1.0305808782577515, 0.8533572554588318, 0.722222089767456]
# Starting Eigen Comp
# Ending Eigen Comp 0.13152027130126953 sec
# {"epoch": 24, "step": 1900, "lr_weights": 0.04997517869093196, "lr_biases": 0.0011994042885823668, "loss": 506.8794250488281, "time": 2520}
# [1.8986353874206543, 1.4406030178070068, 0.8463788032531738, 0.8264720439910889, 0.5870983004570007]
# Starting Eigen Comp
# Ending Eigen Comp 0.13150286674499512 sec
# {"epoch": 24, "step": 1925, "lr_weights": 0.04997404821884449, "lr_biases": 0.0011993771572522676, "loss": 505.0155944824219, "time": 2553}
# [1.7037034034729004, 1.0825715065002441, 0.8713515400886536, 0.7214093208312988, 0.561050295829773]
# Starting Eigen Comp
# Ending Eigen Comp 0.13120698928833008 sec
# {"epoch": 24, "step": 1950, "lr_weights": 0.049972892586843905, "lr_biases": 0.0011993494220842536, "loss": 506.4474792480469, "time": 2587}
# [1.7839258909225464, 1.560019612312317, 0.9540497660636902, 0.7042734622955322, 0.6405138969421387]
# Starting Eigen Comp
# Ending Eigen Comp 0.13248944282531738 sec
# {"epoch": 25, "step": 1975, "lr_weights": 0.04997171179609563, "lr_biases": 0.0011993210831062948, "loss": 504.79339599609375, "time": 2620}
# [1.4422394037246704, 1.2651379108428955, 1.0364718437194824, 0.8419754505157471, 0.5319690704345703]
# Starting Eigen Comp
# Ending Eigen Comp 0.13081836700439453 sec
# {"epoch": 25, "step": 2000, "lr_weights": 0.04997050584779041, "lr_biases": 0.0011992921403469697, "loss": 504.57196044921875, "time": 2653}
# [1.4663150310516357, 1.0296931266784668, 0.8512714505195618, 0.7649673819541931, 0.6098822951316833]
# Starting Eigen Comp
# Ending Eigen Comp 0.13714337348937988 sec
# {"epoch": 25, "step": 2025, "lr_weights": 0.0499692747431444, "lr_biases": 0.0011992625938354654, "loss": 506.06268310546875, "time": 2686}
# [1.6439512968063354, 1.411972165107727, 1.1265705823898315, 0.9244353175163269, 0.7481111884117126]
# Starting Eigen Comp
# Ending Eigen Comp 0.1303873062133789 sec
# {"epoch": 25, "step": 2050, "lr_weights": 0.04996801848339911, "lr_biases": 0.0011992324436015784, "loss": 505.1923828125, "time": 2719}
# [1.44593346118927, 1.2338701486587524, 0.8914408087730408, 0.7767660617828369, 0.6005192399024963]
# Starting Eigen Comp
# Ending Eigen Comp 0.13097333908081055 sec
# {"epoch": 26, "step": 2075, "lr_weights": 0.04996673706982141, "lr_biases": 0.0011992016896757137, "loss": 505.22625732421875, "time": 2752}
# [1.5615170001983643, 1.3779878616333008, 0.9940493702888489, 0.7872973680496216, 0.6305524706840515]
# Starting Eigen Comp
# Ending Eigen Comp 0.1318824291229248 sec
# {"epoch": 26, "step": 2100, "lr_weights": 0.04996543050370355, "lr_biases": 0.0011991703320888849, "loss": 504.484619140625, "time": 2786}
# [1.46414053440094, 1.3038389682769775, 0.9484488368034363, 0.7168352007865906, 0.5987626314163208]
# Starting Eigen Comp
# Ending Eigen Comp 0.13084769248962402 sec
# {"epoch": 26, "step": 2125, "lr_weights": 0.04996409878636313, "lr_biases": 0.0011991383708727151, "loss": 505.88055419921875, "time": 2818}
# [1.5714343786239624, 1.3652231693267822, 0.8903405666351318, 0.5972339510917664, 0.5439513325691223]
# Starting Eigen Comp
# Ending Eigen Comp 0.13109374046325684 sec
# {"epoch": 27, "step": 2150, "lr_weights": 0.049962741919143135, "lr_biases": 0.0011991058060594351, "loss": 504.8501892089844, "time": 2851}
# [1.8473294973373413, 1.3513628244400024, 0.8408948183059692, 0.6967030167579651, 0.602593183517456]
# Starting Eigen Comp
# Ending Eigen Comp 0.13254141807556152 sec
# {"epoch": 27, "step": 2175, "lr_weights": 0.0499613599034119, "lr_biases": 0.0011990726376818854, "loss": 505.3138427734375, "time": 2885}
# [1.658671259880066, 1.3153384923934937, 1.0338817834854126, 0.7167233228683472, 0.6763981580734253]
# Starting Eigen Comp
# Ending Eigen Comp 0.1305546760559082 sec
# {"epoch": 27, "step": 2200, "lr_weights": 0.0499599527405631, "lr_biases": 0.0011990388657735142, "loss": 504.87847900390625, "time": 2918}
# [1.5378692150115967, 1.478498935699463, 0.8350905179977417, 0.72971111536026, 0.6033243536949158]
# Starting Eigen Comp
# Ending Eigen Comp 0.13230323791503906 sec
# {"epoch": 28, "step": 2225, "lr_weights": 0.04995852043201582, "lr_biases": 0.0011990044903683794, "loss": 503.0753173828125, "time": 2951}
# [1.8062233924865723, 1.3326596021652222, 0.9415295720100403, 0.9050679802894592, 0.7108411192893982]
# Starting Eigen Comp
# Ending Eigen Comp 0.1317598819732666 sec
# {"epoch": 28, "step": 2250, "lr_weights": 0.049957062979214456, "lr_biases": 0.0011989695115011468, "loss": 504.7185974121094, "time": 2984}
# [1.4571672677993774, 1.286848783493042, 0.8184327483177185, 0.7892608642578125, 0.5889024138450623]
# Starting Eigen Comp
# Ending Eigen Comp 0.13109397888183594 sec
# {"epoch": 28, "step": 2275, "lr_weights": 0.049955580383628774, "lr_biases": 0.0011989339292070905, "loss": 505.9972839355469, "time": 3018}
# [1.8256562948226929, 1.5684692859649658, 1.0517773628234863, 0.8072869181632996, 0.652279257774353]
# Starting Eigen Comp
# Ending Eigen Comp 0.1320037841796875 sec
# {"epoch": 29, "step": 2300, "lr_weights": 0.04995407264675392, "lr_biases": 0.001198897743522094, "loss": 504.3414001464844, "time": 3051}
# [1.450745701789856, 1.1607916355133057, 0.8724825382232666, 0.6955935955047607, 0.5870787501335144]
# Starting Eigen Comp
# Ending Eigen Comp 0.13003182411193848 sec
# {"epoch": 29, "step": 2325, "lr_weights": 0.04995253977011037, "lr_biases": 0.0011988609544826487, "loss": 504.8593444824219, "time": 3084}
# [1.438018798828125, 1.3702456951141357, 1.0216236114501953, 0.8076368570327759, 0.6005681753158569]
# Starting Eigen Comp
# Ending Eigen Comp 0.13119864463806152 sec
# {"epoch": 29, "step": 2350, "lr_weights": 0.04995098175524394, "lr_biases": 0.0011988235621258544, "loss": 503.46246337890625, "time": 3117}
# [1.6764845848083496, 1.4029101133346558, 1.117864966392517, 1.021559715270996, 0.6943632960319519]
# Starting Eigen Comp
# Ending Eigen Comp 0.13114619255065918 sec
# {"epoch": 30, "step": 2375, "lr_weights": 0.049949398603725825, "lr_biases": 0.0011987855664894198, "loss": 505.2767639160156, "time": 3150}
# [1.8235673904418945, 1.4318467378616333, 1.04212486743927, 0.9028369784355164, 0.7479331493377686]
# Starting Eigen Comp
# Ending Eigen Comp 0.13106679916381836 sec
# {"epoch": 30, "step": 2400, "lr_weights": 0.04994779031715256, "lr_biases": 0.0011987469676116613, "loss": 504.1789855957031, "time": 3184}
# [1.8744714260101318, 1.71995210647583, 1.2277507781982422, 1.002559781074524, 0.6587105989456177]
# Starting Eigen Comp
# Ending Eigen Comp 0.13194012641906738 sec
# {"epoch": 30, "step": 2425, "lr_weights": 0.049946156897146016, "lr_biases": 0.001198707765531504, "loss": 505.575439453125, "time": 3217}
# [1.5483970642089844, 1.3352357149124146, 1.088120460510254, 0.9755116105079651, 0.8681149482727051]
# Starting Eigen Comp
# Ending Eigen Comp 0.13139700889587402 sec
# {"epoch": 31, "step": 2450, "lr_weights": 0.049944498345353416, "lr_biases": 0.0011986679602884818, "loss": 503.57769775390625, "time": 3250}
# [1.467759609222412, 1.1524531841278076, 0.9921649098396301, 0.7619377374649048, 0.5774117112159729]
# Starting Eigen Comp
# Ending Eigen Comp 0.13074469566345215 sec
# {"epoch": 31, "step": 2475, "lr_weights": 0.04994281466344735, "lr_biases": 0.001198627551922736, "loss": 504.0982666015625, "time": 3283}
# [1.5776917934417725, 1.4360706806182861, 1.048532485961914, 0.7995132207870483, 0.5866965651512146]
# Starting Eigen Comp
# Ending Eigen Comp 0.13102340698242188 sec
# {"epoch": 31, "step": 2500, "lr_weights": 0.049941105853125695, "lr_biases": 0.0011985865404750165, "loss": 503.9479064941406, "time": 3317}
# [1.4767258167266846, 1.1548770666122437, 1.0880604982376099, 0.9529232382774353, 0.7094502449035645]
# Starting Eigen Comp
# Ending Eigen Comp 0.13110685348510742 sec
# {"epoch": 31, "step": 2525, "lr_weights": 0.049939371916111745, "lr_biases": 0.0011985449259866816, "loss": 503.71990966796875, "time": 3350}
# [1.5769861936569214, 1.4003496170043945, 1.0878580808639526, 0.9366143345832825, 0.705621600151062]
# Starting Eigen Comp
# Ending Eigen Comp 0.13212156295776367 sec
# {"epoch": 32, "step": 2550, "lr_weights": 0.04993761285415405, "lr_biases": 0.0011985027084996972, "loss": 504.03485107421875, "time": 3383}
# [1.7782047986984253, 1.2530484199523926, 1.0881259441375732, 0.8961763978004456, 0.6199719905853271]
# Starting Eigen Comp
# Ending Eigen Comp 0.1325986385345459 sec
# {"epoch": 32, "step": 2575, "lr_weights": 0.04993582866902658, "lr_biases": 0.0011984598880566378, "loss": 504.4490051269531, "time": 3416}
# [1.7382317781448364, 1.3536839485168457, 1.3231642246246338, 1.1037477254867554, 0.7364839315414429]
# Starting Eigen Comp
# Ending Eigen Comp 0.13127827644348145 sec
# {"epoch": 32, "step": 2600, "lr_weights": 0.04993401936252857, "lr_biases": 0.0011984164647006856, "loss": 501.9153747558594, "time": 3449}
# [1.4498507976531982, 1.3461629152297974, 1.1048712730407715, 0.9581665396690369, 0.6623520255088806]
# Starting Eigen Comp
# Ending Eigen Comp 0.1324176788330078 sec
# {"epoch": 33, "step": 2625, "lr_weights": 0.04993218493648464, "lr_biases": 0.001198372438475631, "loss": 503.6649169921875, "time": 3482}
# [1.5013092756271362, 1.3274275064468384, 1.072391152381897, 0.930850088596344, 0.6600335836410522]
